# %%
import pandas as pd
import numpy as np

# %%
stocklist = pd.read_csv('selected_stocks.csv', index_col = 0)

# %%
stocklist = stocklist['stock_name']

# %%
df = pd.DataFrame(columns= ['stockname', 'avg_profit', 'num_trades'])

# %%
for stockname in stocklist :
    df_all = pd.read_csv("stock_data/"+stockname+".csv", names=('Dates', 'stockVWAP', 'futureVWAP', 'bidPrice', 'askPrice', 'total_value', 'total_size'))
    df_train = df_all[:60000]
    df_train_for_10min = df_train[df_train.index%10 == 0]
    df_train_for_10min = df_train_for_10min.reset_index(drop = True)
    df_final = df_train_for_10min
    
    spread = df_final['askPrice'].max() - df_final['bidPrice'].max()
    
    data = np.array([])
    for i in range(563):
        data = np.append(data, df_final.iloc[i,1] ) 
        
    for i in range(563, 6000):
        data = np.append(data, np.mean(df_final.iloc[i-562:i+1])) 
    
    df_new = pd.DataFrame(data)
    
    no_of_trades=0
    dev_sum=0
    
    for i in range(6000):
        dev = df_final.loc[i,'stockVWAP'] - 0.2 - spread - df_new.loc[i,0]
        if dev>0:
            dev_sum+=dev
            no_of_trades+=1
        if no_of_trades>0:
            dev_mean=dev_sum/no_of_trades
            total_profit=dev_sum
    s = pd.Series([stockname, dev_mean, no_of_trades],index= ['stockname', 'avg_profit', 'num_trades'])
    df = df.append(s,ignore_index=True)

    print(stockname + ":" + str(dev_mean) + ":" + str(no_of_trades))       
df.to_csv("profits_5d.csv")
# Out:
# JPASSOCIAT:4.707986248586628:3215
# GMRINFRA:3.1007563093500594:3436
# SUZLON:6.277076461056183:3259
# IBREALEST:89.45385043838675:2861
# RELCAPITAL:149.6667305758549:3593
# DLF:35.46135303669541:3624
# IDFC:2.181108540491526:1876
# SOUTHBANK:4.400502837474378:2617
# IDFCBANK:1.3435127123664923:540
# BANKBARODA:11.788121283948664:2251
# MANAPPURAM:33.6696395060319:3355
# HINDALCO:17.838769642682326:3407
# TATASTEEL:56.7098306386244:3123
# JINDALSTEL:35.56627188827912:3624
# RCOM:3.3577313196476037:1526
# HDIL:17.72368162975015:3013
# L_TFH:33.24809995182172:3597
# NMDC:4.5299091822311865:605
# ADANIPOWER:2.5482368154907333:1173
# HCC:25.564430044500536:1457
# ICICIBANK:18.750030975709155:3485
# SUNTV:191.95508915746652:3439
# RELINFRA:51.83535395706694:2024
# PNB:15.498372393225978:3159
# JSWSTEEL:18.77199276160543:2121
# APOLLOTYRE:57.409358023726675:2774
# MOTHERSUMI:59.74675372691096:2648
