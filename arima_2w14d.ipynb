# %%
import pandas as pd
import numpy as np
import os
from statsmodels.tsa.arima_model import ARIMA
from pandas.core import datetools

# %%
df_stocks = pd.read_csv('./top25_stocks.csv', index_col = 0)
df_stocks = df_stocks[df_stocks['TimeFrame'] == '2w'].reset_index()
stocks = df_stocks['Stock']
stocks
# Out:
# 0    BEL
# Name: Stock, dtype: object

# %%
predictions = pd.DataFrame(index = range(1000), columns = stocks)

# %%
temp = 0
predictions_all = None
check_empty = 1

# %%
for stockname in stocks :    
    df = pd.read_csv("./stock_data/" + stockname +".csv", names = ('Dates', 'stockVWAP', 'futureVWAP', 'bidPrice', 'askPrice', 'total_value', 'total_size'))
    rng = pd.date_range('2017-01-02 09:16:00', periods=1000, freq='60min')
    df = df.iloc[0:60000]
    df = df[df.index%60 == 0]
    df_new = pd.DataFrame(df['stockVWAP'].values, index = rng)
#     for eack value in df_new we will use arima model on the data before that value to predict
#     future prices upto 262 positions(with the same logic as in the profits one). After that we will calculate the
#     mean of these postions and compare it with the value and make predictions accordingly.
#     Use 0 for 0 for sell, 1 for buy and 0.5 for hold. Sell only when value is > mean + sd and
#     buy when value < mean - sd.
#     Also for the parameters of arima model take p and q in range [0, 1, 2, 3] and d in [0, 1] and find the best model

    for k in range(1000):                        
        df_scan = df_new.iloc[:k]
        # write your arima model here
                                                       
        if best_mdl is None:                                 
            temp = temp + 1                         
        else:
#     calculate the mean of these postions and compare it with the value and make predictions accordingly.
#     Use 0 for 0 for sell, 1 for buy and 0.5 for hold. Sell only when value is > mean + sd and
#     buy when value < mean - sd.

    predictions_single = predictions.values
    
    if check_empty == 1:                                   
        predictions_all = predictions_single
        check_empty = 0
    else:
        predictions_all = np.concatenate([predictions_all,predictions_single])

predictions_new = pd.DataFrame(data=predictions_all, columns = stocks.values)
predictions_new.to_csv("predictions_2w(14d).csv")
print("predictions_2w(14d).csv" + " Ready!!!")
# Out:
# /home/jitesh/anaconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:1127: RuntimeWarning: invalid value encountered in sqrt
#   return rho, np.sqrt(sigmasq)
# /home/jitesh/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/ar_model.py:770: RuntimeWarning: divide by zero encountered in log
#   return np.log(self.sigma2) + (1 + self.df_model) * np.log(nobs)/nobs
# /home/jitesh/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /home/jitesh/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/tsatools.py:584: RuntimeWarning: overflow encountered in exp
#   newparams = ((1-np.exp(-params))/
# /home/jitesh/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/tsatools.py:585: RuntimeWarning: overflow encountered in exp
#   (1+np.exp(-params))).copy()
# ...
